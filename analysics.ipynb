# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('SuperStore_Sales_Dataset.csv')
print(df)
# Out:
#       Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 0                 4918  CA-2019-160304  01-01-2019  07-01-2019
# 1                 4919  CA-2019-160304  02-01-2019  07-01-2019
# 2                 4920  CA-2019-160304  02-01-2019  07-01-2019
# 3                 3074  CA-2019-125206  03-01-2019  05-01-2019
# 4                 8604  US-2019-116365  03-01-2019  08-01-2019
# ...                ...             ...         ...         ...
# 5896               907  CA-2020-143259  30-12-2020  03-01-2021
# 5897              1297  CA-2020-115427  30-12-2020  03-01-2021
# 5898              5092  CA-2020-156720  30-12-2020  03-01-2021
# 5899               909  CA-2020-143259  30-12-2020  03-01-2021
# 5900              5093  CA-2020-151450  31-12-2020  04-01-2021
#
#            Ship Mode Customer ID      Customer Name    Segment        Country  \
# 0     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# ...

# %%
df.tail()
# Out:
#       Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 5896               907  CA-2020-143259  30-12-2020  03-01-2021
# 5897              1297  CA-2020-115427  30-12-2020  03-01-2021
# 5898              5092  CA-2020-156720  30-12-2020  03-01-2021
# 5899               909  CA-2020-143259  30-12-2020  03-01-2021
# 5900              5093  CA-2020-151450  31-12-2020  04-01-2021
#
#            Ship Mode Customer ID      Customer Name    Segment        Country  \
# 5896  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5897  Standard Class    EB-13975         Erica Bern  Corporate  United States
# 5898  Standard Class    JM-15580      Jill Matthias   Consumer  United States
# 5899  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5900  Standard Class    JM-15580      Jill Matthias   Consumer  United States
#
#                City  ...         Category Sub-Category  \
# 5896  New York City  ...        Furniture    Bookcases
# ...

# %%
list(df.columns)
# Out:
# ['Row ID+O6G3A1:R6',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Profit',
#  'Returns',
#  'Payment Mode',
#  'ind1',
#  'ind2']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5901 entries, 0 to 5900
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID          5901 non-null   object
#  2   Order Date        5901 non-null   object
#  3   Ship Date         5901 non-null   object
#  4   Ship Mode         5901 non-null   object
#  5   Customer ID       5901 non-null   object
#  6   Customer Name     5901 non-null   object
#  7   Segment           5901 non-null   object
#  8   Country           5901 non-null   object
#  9   City              5901 non-null   object
#  10  State             5901 non-null   object
#  11  Region            5901 non-null   object
#  12  Product ID        5901 non-null   object
#  13  Category          5901 non-null   object
#  14  Sub-Category      5901 non-null   object
#  15  Product Name      5901 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID+O6G3A1:R6       0
# Order ID               0
# Order Date             0
# Ship Date              0
# Ship Mode              0
# Customer ID            0
# Customer Name          0
# Segment                0
# Country                0
# City                   0
# State                  0
# Region                 0
# Product ID             0
# Category               0
# Sub-Category           0
# Product Name           0
# Sales                  0
# Quantity               0
# Profit                 0
# Returns             5614
# Payment Mode           0
# ind1                5901
# ind2                5901
# dtype: int64

# %%
df.describe()
# Out:
#        Row ID+O6G3A1:R6        Sales     Quantity       Profit  Returns  ind1  \
# count       5901.000000  5901.000000  5901.000000  5901.000000    287.0   0.0
# mean        5022.422471   265.345589     3.781901    29.700408      1.0   NaN
# std         2877.977184   474.260645     2.212917   259.589138      0.0   NaN
# min            1.000000     0.836000     1.000000 -6599.978000      1.0   NaN
# 25%         2486.000000    71.976000     2.000000     1.795500      1.0   NaN
# 50%         5091.000000   128.648000     3.000000     8.502500      1.0   NaN
# 75%         7456.000000   265.170000     5.000000    28.615000      1.0   NaN
# max         9994.000000  9099.930000    14.000000  8399.976000      1.0   NaN
#
#        ind2
# count   0.0
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN

# %%
print(df['Product Name'].max())
# Out:
# netTALK DUO VoIP Telephone Service

# %%
print(df[['Returns', 'Customer Name']].value_counts())
# Out:
# Returns  Customer Name
# 1.0      Seth Vernon         14
#          Stefania Perrino     8
#          Dan Reichenbach      8
#          Patrick Ryan         7
#          Greg Guthrie         7
#                              ..
#          Shui Tom             1
#          Sue Ann Reed         1
#          Tracy Collins        1
#          Troy Blackwell       1
#          Vivek Sundaresam     1
# Name: count, Length: 99, dtype: int64

# %%
print(df[['Returns', 'Product Name']].value_counts())
# Out:
# Returns  Product Name
# 1.0      Staple remover                                                          3
#          iHome FM Clock Radio with Lightning Dock                                2
#          Wilson Jones Clip & Carry Folder Binder Tool for Ring Binders, Clear    2
#          Binding Machine Supplies                                                2
#          GuestStacker Chair with Chrome Finish Legs                              2
#                                                                                 ..
#          Advantus T-Pin Paper Clips                                              1
#          Akro Stacking Bins                                                      1
#          Alphabetical Labels for Top Tab Filing                                  1
#          Ampad #10 Peel & Seel Holiday Envelopes                                 1
#          Acco Perma 4000 Stacking Storage Drawers                                1
# Name: count, Length: 265, dtype: int64

# %%
print(df['Profit'].max())
# Out:
# 8399.976

# %%
print(df['Sales'].sum())
# Out:
# 1565804.3232

# %%
print(df['Order Date'].max())
# Out:
# 31-12-2020

# %%
print(df['Order ID'].max())
# Out:
# US-2020-169551

# %%
df[['Quantity', 'Customer Name']].value_counts()
# Out:
# Quantity  Customer Name
# 2         Clay Ludtke        9
#           Damala Kotsonis    8
# 3         Raymond Buch       8
# 2         Edward Hooks       8
#           Seth Vernon        8
#                             ..
# 1         Anna Gayman        1
#           Angele Hood        1
#           Anemone Ratner     1
#           Alyssa Tate        1
#           Alex Avila         1
# Name: count, Length: 3334, dtype: int64

# %%
print(df[['Order Date', 'Customer Name']].value_counts())
# Out:
# Order Date  Customer Name
# 20-09-2020  Seth Vernon        14
# 02-09-2020  Ann Chong          12
# 11-12-2019  William Brown      11
# 05-02-2019  Paul Prost         11
# 13-09-2019  Alejandro Grove    10
#                                ..
# 01-04-2020  George Bell         1
#             John Castell        1
# 01-05-2020  Sanjit Jacobs       1
# 01-06-2020  Barry Blumstein     1
#             Barry Weirich       1
# Name: count, Length: 2993, dtype: int64

# %%
df['Region'].max()
# Out:
# 'West'

# %%
df[['Order Date','Region']].max()
# Out:
# Order Date    31-12-2020
# Region              West
# dtype: object

# %%
df[['Product Name','Region']].max()
# Out:
# Product Name    netTALK DUO VoIP Telephone Service
# Region                                        West
# dtype: object

# %%
df[['Order Date', 'Product Name']].value_counts()
# Out:
# Order Date  Product Name
# 09-11-2020  Adjustable Depth Letter/Legal Cart                              2
# 15-04-2019  Imation Secure+ Hardware Encrypted USB 2.0 Flash Drive; 16GB    2
# 03-12-2020  Memorex Micro Travel Drive 16 GB                                2
# 06-11-2020  Easy-staple paper                                               2
# 09-12-2020  Economy Binders                                                 2
#                                                                            ..
# 31-12-2019  Lock-Up Easel 'Spel-Binder'                                     1
#             Newell 345                                                      1
#             Tennsco Industrial Shelving                                     1
#             Things To Do Today Pad                                          1
# 01-01-2020  Fellowes Superior 10 Outlet Split Surge Protector               1
# Name: count, Length: 5879, dtype: int64

# %%
df['Region'].value_counts().plot(kind='bar')
plt.xlabel('Region')
plt.ylabel('Quantity')
plt.show()

# %%
df['Order Date'].value_counts().sort_index().plot(kind='bar')
plt.xlabel('Order Date')
plt.ylabel('Quantity')
plt.show()
